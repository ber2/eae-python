# %% [markdown]
# # Ejercicios Día 6: Inferencia Estadística
#
# **Business Analytics & Data Science** | EAE Business School | 9 junio 2026
#
# Usaremos Hotel Bookings. Rellenad las celdas; soluciones al final.

# %%
import pandas as pd, numpy as np
from scipy import stats
import plotly.express as px
dfh = pd.read_csv("https://raw.githubusercontent.com/ber2/eae-python/main/data/hotel_bookings.csv")
dfh.head()

# %% [markdown]
# ## Ejercicio 1: Intervalo de confianza
#
# Calculad el IC 95% para el ADR (precio medio diario) de todas las reservas.

# %%
# Vuestra solución aquí

# %% [markdown]
# ## Ejercicio 2: ¿Cancelan más quienes piden cambios?
#
# ¿La probabilidad de cancelación (`is_canceled`) es mayor cuando el tipo de
# depósito (`deposit_type`) es "Non Refund"? Construid la tabla de contingencia,
# calculad las tasas de cancelación y aplicad un test chi-cuadrado.

# %%
# Vuestra solución aquí

# %% [markdown]
# ## Ejercicio 3: ADR ciudad vs resort
#
# Comparad el ADR medio entre `City Hotel` y `Resort Hotel` con un t-test.
# **Antes** de mirar el p-value, dibujad un box plot. ¿Qué concluís? ¿El resultado
# es estadísticamente significativo?

# %%
# Vuestra solución aquí
