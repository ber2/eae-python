# %% [markdown]
# # Ejercicios Día 5: Estadísticos de Resumen
#
# **Business Analytics & Data Science** | EAE Business School | 8 junio 2026
#
# Rellenad las celdas vacías. Soluciones al final.

# %%
import pandas as pd, numpy as np
import plotly.express as px
df = pd.read_csv("https://raw.githubusercontent.com/ber2/eae-python/main/data/Houses_Barcelona_samp.csv")

# %% [markdown]
# ## Ejercicio 1: Resumen de `sqrmts`
#
# 1. Media, mediana y moda de los metros cuadrados.
# 2. Desviación estándar e IQR.
# 3. ¿Cuántos outliers hay (regla 1.5 × IQR)?

# %%
# Vuestra solución aquí

# %% [markdown]
# ## Ejercicio 2: Frecuencias
#
# 1. Tabla de frecuencias relativas de `type`.
# 2. ¿Qué porcentaje de propiedades son "Piso"?
# 3. Precio medio por tipo de propiedad (groupby).

# %%
# Vuestra solución aquí

# %% [markdown]
# ## Ejercicio 3: Correlación
#
# 1. Calculad la matriz de correlación de `price`, `sqrmts`, `rooms`, `bathrooms`.
# 2. ¿Qué par tiene la correlación más fuerte (sin contar la diagonal)?
# 3. Dibujad un scatter del par más correlacionado.

# %%
# Vuestra solución aquí
